# %% [markdown]
# # Using Pandas

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 200)
## to make it possible to display multiple output inside one cell 
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# <b>load the data from the vehicles.csv file into pandas data frame

# %%
## Your Code here
import pandas as pd
df_cars= pd.read_csv("C:/Users/dengd/Documents/GitHub/IronDuo/Class_Materials/Pandas/Labs/data/vehicles.csv")
df_cars
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %% [markdown]
# First exploration of the dataset:
#
# - How many observations does it have?
# - Look at all the columns: do you understand what they mean?
# - Look at the raw data: do you see anything weird?
# - Look at the data types: are they the expected ones for the information the column contains?

# %%
# 1. How many observations does it have?
# df_cars_num = df_cars[df_cars.columns[0]].count() # .columns method get all columns then choose [0](the first one)
df_cars_num = df_cars["Make"].count()
print(f'There are :{df_cars_num} observations.')

# shape function 
df_cars.shape
# Out:
# There are :35952 observations.
# (35952, 15)

# %%
# 2. Look at all the columns: do you understand what they mean?
df_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35952 entries, 0 to 35951
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Make                     35952 non-null  object
#  1   Model                    35952 non-null  object
#  2   Year                     35952 non-null  int64
#  3   Engine Displacement      35952 non-null  float64
#  4   Cylinders                35952 non-null  float64
#  5   Transmission             35952 non-null  object
#  6   Drivetrain               35952 non-null  object
#  7   Vehicle Class            35952 non-null  object
#  8   Fuel Type                35952 non-null  object
#  9   Fuel Barrels/Year        35952 non-null  float64
#  10  City MPG                 35952 non-null  int64
#  11  Highway MPG              35952 non-null  int64
#  12  Combined MPG             35952 non-null  int64
#  13  CO2 Emission Grams/Mile  35952 non-null  float64
# ...

# %%
# 3. Look at the raw data: do you see anything weird?
# I cannot see anything weird.

# %%
# 4.Look at the data types: are they the expected ones for the information the column contains?
def unique_col_values():
    for column in df_cars:
        print("{} | {} | {}".format(
            df_cars[column].name, len(df_cars[column].unique()), df_cars[column].dtype
        ))

unique_col_values()
# Out:
# Make | 127 | object
# Model | 3608 | object
# Year | 34 | int64
# Engine Displacement | 65 | float64
# Cylinders | 9 | float64
# Transmission | 45 | object
# Drivetrain | 8 | object
# Vehicle Class | 34 | object
# Fuel Type | 13 | object
# Fuel Barrels/Year | 123 | float64
# City MPG | 48 | int64
# Highway MPG | 49 | int64
# Combined MPG | 46 | int64
# CO2 Emission Grams/Mile | 575 | float64
# Fuel Cost/Year | 55 | int64

# %% [markdown]
# ### Cleaning and wrangling data
#
# - Some car brand names refer to the same brand. Replace all brand names that contain the word "Dutton" for simply "Dutton". If you find similar examples, clean their names too. Use `loc` with boolean indexing.
#
# - Convert CO2 Emissions from Grams/Mile to Grams/Km
#
# - Create a binary column that solely indicates if the transmission of a car is automatic or manual. Use `pandas.Series.str.startswith` and .
#
# - convert MPG columns to km_per_liter

# %% [markdown]
# Note:
# <br>Converting Grams/Mile to Grams/Km
#
# 1 Mile = 1.60934 Km
#
# Converting Gallons to Liters
#
# 1 Gallon = 3.78541 Liters

# %%
# df_cars["Make"] =df_cars["Make"].str.replace(r'(.*)[dD]utton(.*)",'Dutton',regex =True)

# %%
# Question1
# df_cars.loc[df_cars["Make"].str.find("Dutton")!=-1,"Make"]="Dutton"

# %%
df_cars.loc[df_cars["Make"].str.find("Dutton")!=-1]
# Out:
#                                      Make               Model  Year  \
# 11012                  E. P. Dutton, Inc.       Funeral Coach  1985
# 30164  S and S Coach Company  E.p. Dutton  Funeral Coach  2WD  1984
# 31754    Superior Coaches Div E.p. Dutton  Funeral Coach  2WD  1984
#
#        Engine Displacement  Cylinders     Transmission         Drivetrain  \
# 11012                  4.1        8.0  Automatic 4-spd  Front-Wheel Drive
# 30164                  6.0        8.0  Automatic 3-spd      2-Wheel Drive
# 31754                  6.0        8.0  Automatic 3-spd      2-Wheel Drive
#
#                      Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 11012     Special Purpose Vehicles   Regular          19.388824        15
# 30164  Special Purpose Vehicle 2WD   Regular          32.961000         9
# 31754  Special Purpose Vehicle 2WD   Regular          32.961000        10
#
#        Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# ...

# %%
# Question2. Convert CO2 Emissions from Grams/Mile to Grams/Km
CO2_rename = df_cars.rename(columns ={"CO2 Emission Grams/Mile": "CO2 Emission Grams/Km"})
CO2_rename["CO2 Emission Grams/Km"]= CO2_rename["CO2 Emission Grams/Km"]/1.60934
CO2_rename
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %%
# Question3_method1
df_cars["Is Auto?"] = CO2_rename.loc[df_cars["Transmission"].str.find("Auto")!=-1,"Make"]= "Dutton"
df_cars
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %%
# Question1_ method2
df_cars["Is Auto??"] = df_cars["Transmission"].str.startswith("Auto")
df_cars
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %%
# Question4. convert MPG columns to km_per_liter
CO2_rename1 = CO2_rename.rename(columns ={"City MPG": "City KPL","Highway MPG": "Highway KPL","Combined MPG":"Combined KPL"})
CO2_rename1
CO2_rename2 = CO2_rename1[["City KPL","Highway KPL","Combined KPL"]]* (3.78541/1.60934)
CO2_rename2
# Out:
#          Make                Model  Year  Engine Displacement  Cylinders  \
# 0      Dutton    DJ Po Vehicle 2WD  1984                  2.5        4.0
# 1      Dutton     FJ8c Post Office  1984                  4.2        6.0
# 2      Dutton  Post Office DJ5 2WD  1985                  2.5        4.0
# 3      Dutton  Post Office DJ8 2WD  1985                  4.2        6.0
# 4      Dutton                  GNX  1987                  3.8        6.0
# ...       ...                  ...   ...                  ...        ...
# 35947  Dutton         fortwo coupe  2013                  1.0        3.0
# 35948  Dutton         fortwo coupe  2014                  1.0        3.0
# 35949  Dutton         fortwo coupe  2015                  1.0        3.0
# 35950  Dutton         fortwo coupe  2016                  0.9        3.0
# 35951   smart         fortwo coupe  2016                  0.9        3.0
#
#           Transmission        Drivetrain                Vehicle Class  \
# ...

# %% [markdown]
# ### Gathering insights:
#
# - How many car makers are there? How many models? Which car maker has the most cars in the dataset?
#
# - When were these cars made? How big is the engine of these cars?
#
# - What's the frequency of different transmissions, drivetrains and fuel types?
#
# - What's the car that consumes the least/most fuel?

# %%
# 1.1 How many car makers are there? How many models? Which car maker has the most cars in the dataset?
num_makers= len(df_cars["Make"].unique())
print(f'There are {num_makers} makers.')

# 1.2 How many models?
num_models = len(df_cars["Model"].unique())
print(f'There are {num_makers} models.')

# 1.3 Which car maker has the most cars in the dataset?
most_car = df_cars["Make"].value_counts()
most_car_maker = most_car.idxmax() # idxmax get the name(index) of maximum value
print(f'{most_car_maker} has the most cars.')
# Out:
# There are 127 makers.
# There are 127 models.
# Chevrolet has the most cars.

# %%
# 2.1 When were these cars made? 

most_car_filter = df_cars["Make"].str.startswith("Chevrolet") #str.startswith() check if a string starts with a specified substring.
df_cars.loc[most_car_filter, ["Make",'Model', 'Year']].sort_values(by="Year") # sort_values(by="") function can sort the column by name

# 2.2 How big is the engine of these cars?
most_car_filter = df_cars["Make"].str.startswith("Chevrolet")
df_cars.loc[most_car_filter, ["Make",'Model', 'Engine Displacement']].sort_values(by="Engine Displacement")
# Out:
#            Make             Model  Year
# 4745  Chevrolet    C20 Pickup 2WD  1984
# 7426  Chevrolet  Suburban K10 4WD  1984
# 6319  Chevrolet    K20 Pickup 4WD  1984
# 6318  Chevrolet    K20 Pickup 4WD  1984
# 6317  Chevrolet    K20 Pickup 4WD  1984
# ...         ...               ...   ...
# 4970  Chevrolet            Camaro  2017
# 6955  Chevrolet                SS  2017
# 6954  Chevrolet                SS  2017
# 5725  Chevrolet       Equinox FWD  2017
# 7917  Chevrolet              Volt  2017
#
# [3643 rows x 3 columns]
#            Make             Model  Engine Displacement
# 6513  Chevrolet             Metro                  1.0
# 7315  Chevrolet            Sprint                  1.0
# 7313  Chevrolet            Sprint                  1.0
# 7337  Chevrolet       Sprint Plus                  1.0
# 7336  Chevrolet       Sprint Plus                  1.0
# ...         ...               ...                  ...
# 5542  Chevrolet          Corvette                  7.0
# ...

# %%
# 3.What's the frequency of different transmissions, drivetrains and fuel types?
fre_trans = df_cars["Transmission"].value_counts()

# %%
fre_dri = df_cars["Drivetrain"].value_counts()

# %%
fre_types =  df_cars["Fuel Type"].value_counts()

# %%
# 4.What's the car that consumes the least/most fuel?
rank_all = df_cars.sort_values(by="Fuel Barrels/Year",ascending= False)# ascending= False (high-low)
max_cost = rank_all["Fuel Barrels/Year"].max()
max_cost
min_cost = rank_all["Fuel Barrels/Year"].min()
min_cost

# consumes the most 
car_consume_most =rank_all.loc[ rank_all["Fuel Barrels/Year"] == max_cost]
car_consume_most
car_consume_most_name = car_consume_most["Make"].unique()[0] # [0]前面是一个array
car_consume_most_name
print(f'{car_consume_most_name} consumes the most fuel.')
# Out:
# 47.08714285714285
# 0.06
#               Make     Model  Year  Engine Displacement  Cylinders  \
# 20898  Lamborghini  Countach  1990                  5.2       12.0
# 20896  Lamborghini  Countach  1988                  5.2       12.0
# 20895  Lamborghini  Countach  1987                  5.2       12.0
# 20894  Lamborghini  Countach  1986                  5.2       12.0
# 20897  Lamborghini  Countach  1989                  5.2       12.0
#
#        Transmission        Drivetrain Vehicle Class Fuel Type  \
# 20898  Manual 5-spd  Rear-Wheel Drive   Two Seaters   Premium
# 20896  Manual 5-spd  Rear-Wheel Drive   Two Seaters   Premium
# 20895  Manual 5-spd  Rear-Wheel Drive   Two Seaters   Premium
# 20894  Manual 5-spd  Rear-Wheel Drive   Two Seaters   Premium
# 20897  Manual 5-spd  Rear-Wheel Drive   Two Seaters   Premium
#
#        Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 20898          47.087143         6           10             7
# ...

# %%
# consumes the least 
car_consume_least =rank_all.loc[ rank_all["Fuel Barrels/Year"] == min_cost]
car_consume_least
car_consume_least_name = car_consume_least["Make"].unique()[0] # [0]前面是一个array
car_consume_least_name
print(f'{car_consume_least_name} consumes the least fuel.')
# Out:
#         Make              Model  Year  Engine Displacement  Cylinders  \
# 17396  Honda  Civic Natural Gas  2013                  1.8        4.0
# 17398  Honda  Civic Natural Gas  2015                  1.8        4.0
# 17397  Honda  Civic Natural Gas  2014                  1.8        4.0
# 17395  Honda  Civic Natural Gas  2012                  1.8        4.0
#
#           Transmission         Drivetrain Vehicle Class Fuel Type  \
# 17396  Automatic 5-spd  Front-Wheel Drive  Compact Cars       CNG
# 17398  Automatic 5-spd  Front-Wheel Drive  Compact Cars       CNG
# 17397  Automatic 5-spd  Front-Wheel Drive  Compact Cars       CNG
# 17395  Automatic 5-spd  Front-Wheel Drive  Compact Cars       CNG
#
#        Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 17396               0.06        27           38            31
# 17398               0.06        27           38            31
# 17397               0.06        27           38            31
# ...

# %% [markdown]
# <b> (Optional)

# %% [markdown]
# What brand has the worse CO2 Emissions on average?
#
# Hint: use the function `sort_values()`

# %%
emissions_mean = df_cars.groupby('Make')['CO2 Emission Grams/Mile'].mean().sort_values(ascending=False).idxmax()
print(f'{emissions_mean} has the worse CO2 Emissions on average.')
# Out:
# Vector has the worse CO2 Emissions on average.

# %% [markdown]
# Do cars with automatic transmission consume more fuel than cars with manual transmission on average?

# %%
## Your Code is here 
CO2_rename.groupby('Is Auto?')['CO2 Emission Grams/Km'].mean()
print(f'Automatic transmission consumes more fuel than cars with manual transmission on average.')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [22], line 2
#       1 ## Your Code is here
# ----> 2 CO2_rename.groupby('Is Auto?')['CO2 Emission Grams/Km'].mean()
#       3 print(f'Automatic transmission consumes more fuel than cars with manual transmission on average.')
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:7721, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7716 axis = self._get_axis_number(axis)
#    7718 # https://github.com/python/mypy/issues/7642
#    7719 # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7720 # "Union[bool, NoDefault]"; expected "bool"
# -> 7721 return DataFrameGroupBy(
#    7722     obj=self,
#    7723     keys=by,
#    7724     axis=axis,
#    7725     level=level,
#    7726     as_index=as_index,
#    7727     sort=sort,
# ...

# %%
# series has index, array doesn't have it. 
# array + index = series /series +column name= dateframe
