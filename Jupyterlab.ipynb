# %% [markdown]
# # Introduce Holiday

# %% [markdown]
# ## Table of Content
# * [My Traveling in 2019](#name)
# * [Dream Destination-Zermatt](#name_1)

# %%
input("Enter your name:")

# %% [markdown]
# ## My Traveling in 2019-The Great Wall <a name="name"></a>

# %% [markdown]
# ![2020_10_27_15_15_IMG_9520.JPG](attachment:2020_10_27_15_15_IMG_9520.JPG)

# %% [markdown]
# ## Dream Destination in 2023 - Zermatt<a name="name_1"></a>

# %% [markdown]
# ![zermatt-im-kanton-wallis-ist-bei-skifahrern-.jpg](attachment:zermatt-im-kanton-wallis-ist-bei-skifahrern-.jpg)

# %% [markdown]
# ### Video of Zermatt

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('CeF8ZDADEBE',width=800, height=500)

# %%
### Top 3 things to do in Zermatt
- **Matterhorn and Scenic Hikes**
- **All Year Destination**
- **Alpine Culture**
