# %% [markdown]
# # Day1
# ## 1. Git
# **Git Clone**: This command is used to create a local copy of a remote repository. It downloads the entire repository and its entire history to the local machine. The syntax for the command is "git clone <repository-url>".
#
# **Git Fetch**: This command is used to download new commits and branches from a remote repository to the local machine. It does not merge the changes into the local branches, but it makes the new commits available for merging or inspecting. The syntax for the command is "git fetch <remote>".
#
# **Git Pull**: This command is used to download new commits and branches from a remote repository and merge them into the local branches. It is a combination of the git fetch and git merge commands. The syntax for the command is "git pull <remote> <branch>".
#
# **Git Push**: This command is used to upload local commits to a remote repository. It updates the remote repository with the new commits. The syntax for the command is "git push <remote> <branch>".
#
# git commit、git push、git pull、 git fetch、git merge 的含义与区别
#
# git commit：是将本地修改过的文件提交到本地库中；
# git push：是将本地库中的最新信息发送给远程库；
# git pull：是从远程获取最新版本到本地，并自动merge；
# git fetch：是从远程获取最新版本到本地，不会自动merge；
# git merge：是用于从指定的commit(s)合并到当前分支，用来合并两个分支；
#
# ## 2.Markdown语法
# 1. #title 一级标题
# 2. ##subtitle 二级标题
# 3. ###subsubtitle 三级标题
# 4. Boldface: **word** 加粗
# 5. Italics: *word* 斜体
# 6. Mathematical symbols:
#   - $ latex equation (inline ) 文中添加公式(要夹在2个$中间噢）
#   - $$ latex equation ( outline ) 公式居中，且独占一行！
# 7. Bullets: - and a space 圆点
# 8. Linebreaks: <br> 换行
# 9. Links: [ text link ] ( link )加链接
#
# ## 3.Data Type
# 不可变数据（3 个）：Number、String、Tuple；<br>
# 可变数据（3 个）：List、Dictionary、Set<br>
# 除了set()，其它都是可以排序的<br>
#
# ### string
# 字符串运算
#
# 下表实例变量a值为字符串 "Hello"，b变量值为 "Python"：
#
# +   **字符串连接** a + b 输出结果： HelloPython<br>
# *	**重复输出字符串**	 a*2 输出结果：HelloHello <br>
# * []	 **通过索引获取字符串中字符**	a[1] 输出结果 e,因为python的第一位是0；<br>
# * [ : ]	 **截取字符串中的一部分**	a[1:4] 输出结果 ell<br>
# * in	 **成员运算符 - 如果字符串中包含给定的字符返回 True**	H in a 输出结果 1<br>
# * not in	 **成员运算符 - 如果字符串中不包含给定的字符返回 True**	M not in a 输出结果 1<br>
#
# ### List
# 内置函数
# * len()  len 函数返回列表中的元素个数 <br>
# * max()  max 函数返回列表元素最大值<br>
# * min()  min 函数返回列表元素最大值<br>
# * sorted(iterable, cmp=None, key=None, reverse=False这是升序)reverse = True，可实现降序排序。<br>
# * append() 在列表的末尾追加新的内容 <br>
# * count() 统计某个元素在列表中出现的次数<br>
# * extend() 追加内容，它可以在列表的末尾一次性追加另一个序列中的多个值，也就是用新列表扩展原有列表<br>
#  a =[1,2,3]<br>
#  b = [4,5,6]<br>
#  a.extend(b)<br>
#  a<br>
#  [1, 2, 3, 4, 5, 6]<br>
# * index() 从列表中找出某个元素第一次匹配的位置的索引位置(从0开始噢），如果列表中有2个相同的元素，只找第一个。<br>
# * insert() 用于像列表中插入对象<br>
# * pop() 移除列表中的一个元素（默认是最后一个），并且返回该元素的值<br>
# * remove() 用于移除列表中第一个匹配的元素<br>
# * reverse() 将列表中的元素进行反转操作(123变成321）<br>
# * sort() 用于在原位置排序，‘原位置排序’意味着改变原来的列表而让列表中的元素有顺序排列<br>
# * clear() 方法用于清空列表<br>
# * copy() 方法是复制列表<br>
# * 切片： 变量的名字[start: end: step]
#
# ### Tuple
# 元组（tuple）与列表类似（戴了枷锁的列表），不同之处在于元组的元素不能修改,组中的元素类型也可以不相同。<br>
#
# Python 的元组与列表类似，不同之处在于元组的元素不能修改。元组使用小括号()，列表使用方括号[]。<br>
# *  len() 元组求长度使用运算函数 <br>
# *  两个甚至对个元组的连接使用 + 连接符<br>
#
# ### Set
# 集合是由**不重复元素**组成的**无序**的集<br>。使用大括号 {} 或者 set() 函数创建集合，注意：创建一个空集合必须用 set() 而不是 {} ，因为 {} 是用来创建一个空字典。<br>
# * s.add()/s.update() 元素 x 添加到集合 s 中<br>
# * s.remove()/s.disard() 将元素 x 从集合 s 中移除，如果元素不存在，则会发生错误。<br>
# * s.pop() 随机删除集合中的一个元素<br>
# * len()/clear() 跟之前的一样 <br>
# * difference() 两个集合的差集返回一个集合，元素包含在集合 x ，但不在集合 y 【返回一个新的集合】<br>
# * difference_update() 方法用于移除两个集合中都存在的元素【直接在原集合删除，没有返回值】<br>
# * intersection() 用于返回交集，返回一个新的集合【返回一个新的集合】<br>
# * intersection_update()  用于获取两个或更多集合中都重叠的元素，即计算交集【直接在原集合移除，没有返回值】<br>
# * union() 返回两个集合的并集，即包含了所有集合的元素，重复的元素只会出现一次，返回值返回一个新的集合<br>
# * isdisjoint() 方法用于判断两个集合是否包含相同的元素， 如果没有返回 True，否则返回 False<br>
# * issubset() 方法用于判断集合的所有元素是否都包含在指定集合中，如果是则返回 True，否则返回 False。<br>
# * issuperset() 方法用于判断指定集合的所有元素是否都包含在原始的集合中，如果是则返回 True，否则返回 False <br>
#
# ### Dictionary
# **现在有顺序了**,字典的key必须为不可变类型，且不能重复。创建空字典使用 {} <br>
# * len() 方法计算字典元素个数（key的总个数）<br>
# * str() 方法输出字典中可以打印的字符串标识<br>
# * type() 方法返回输入的变量类型，如果变量是字典就返回字典类型 <br>
#
# ##4. Numpy
# * import library_name - if we want to use all the functions included in the library.if the library has one function which has the same name as another we defined, one function will replace the previous one.如果我们想用所有library里的函数，但是有一个问题，如果library中的函数名字和我们定义的函数名字一样的话，那么一个将会取代前一个。
# * import library_name as alias 可以解决前面的问题 (** import numpy as np)
# * from library_name -is used when we only need a specific function from the library.
# * The basic variables in Numpy are **arrays**（必须是same type)
# * The **size** of an array is the total number of elements in every list
# * The **shape** of an array is the size of the array along each dimension (e.g. number of rows and number of columns for a two-dimensional array)
#
# ## Pandas
# * import pandas as pd
# * The primary data structures in Pandas are **Series** and **DataFrames**
#  1.array 没有index列
#  2.series 有初始index 01234....
#  3.array + series = dataframe
# *
#
# map()是一个python内置的function
# print()
# len()
#
# ## 读取CSV文件
# pd.read_csv(filepath, delimiter=',', header=0, names=None, index_col=None, usecols=None, skiprows=None, nrows=None)
#
# DataFrame.to_csv(filename, sep=',', index=True, header=True)
# * index : If set to True, the index of the DataFrame will be written to the CSV file as a column. index会读入进来

# %% [markdown]
# ### 重要的function

# %%
* 【改列名】：file3_rename = file3.rename(columns ={"Gender": "GENDER",'ST':'State'},inplace=True # inplace的意思是在原文件上改；
* 【对文件进行排序】： file1_1 = sorted(list(file1.columns))       
* 【合并两个文件】：
def load_original_data():
    
    return pd.concat([file1,file2,file3_rename], axis=0)
* 【使列名小写(Standardizing header names)】:
def lower_case_column_names(hk_df): 
    lab_Customer_df.columns=[i.lower() for i in lab_Customer_df.columns] # 让每一个i都变成小写
    return lab_Customer_df
lab_Customer_df_lowercase = lower_case_column_names(lab_Customer_df)
lab_Customer_df_lowercase 
* 【去除重复值】：lab_Customer_df.drop_duplicates() 
* 【删除一列】：
def drop_columns(lab_Customer_df):
    lab_Customer_df.drop(columns=['customer'], inplace=True)
    return lab_Customer_df
drop_columns(lab_Customer_df)
* 【重新排列一列】：
1. list(lab_Customer_df) # 先把所有的列弄出来
2. lab_Customer_df = lab_Customer_df[[ 所有的列]]
3. lab_Customer_df['gender'].unique() # 根据gender来清理数据，首先要弄清楚gender在表格里有哪些表达方式
4. # 根据gender来整理数据
def clean_gender(x):
    if x in ['M', 'Male']:
        return 'Male'
    elif x in ['F', 'female','Female']:
        return 'Female'
    elif np.nan:  pass
    else:
        return 'U'
lab_Customer_df['gender'] = list(map(clean_gender, lab_Customer_df['gender'])) 
lab_Customer_df   
5. 【去掉字符串中的某一个字符】
lab_Customer_df['customer'] = lab_Customer_df['customer'].str.rstrip("%").astype(float)
6. 【取出字符串中的第二个字符】
lab_Customer_df["complaints"] = lab_Customer_df["complaints"].where(lab_Customer_df["complaints"].str.len() > 1,other=' ').str.slice(2,3)

# %%
Seaborn library needs matplotlib.

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

* Matplotlib
import matplotlib.pyplot as plt
* Axis functions in Matplotlib
