# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.preprocessing import PowerTransformer
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

import statsmodels.api as sm
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
pd.options.display.max_rows = 50

# %%
# import the data
df = pd.read_excel('D:/Germany/data analysis/Ironhack/course/dataset/CANNUSE_database_dataset_19_03_2021.xlsx')

# Display the data
df
# Out:
#      Unnamed: 0                 Unnamed: 1        Unnamed: 2      Unnamed: 3  \
# 0            Id                  Reference  Publication year  Reference type
# 1             1         Abbas et al., 2013              2013             Res
# 2             2         Abbas et al., 2019              2019             Res
# 3             2         Abbas et al., 2019              2019             Res
# 4             2         Abbas et al., 2019              2019             Res
# ...         ...                        ...               ...             ...
# 2326        648          Aziz et al., 2016              2016             Res
# 2327        648          Aziz et al., 2016              2016             Res
# 2328        648          Aziz et al., 2016              2016             Res
# 2329        648          Aziz et al., 2016              2016             Res
# 2330        649  Babu Jayanth et al., 2020              2020             Res
#
#      Unnamed: 4          Unnamed: 5       Unnamed: 6       Unnamed: 7  \
# 0       Country              Region            Taxon  Vernacular name
# 1      Pakistan    Gilgit-Baltistan  Cannabis sativa          Thonchi
# 2      Pakistan    Gilgit-Baltistan  Cannabis sativa          Thunchi
# 3      Pakistan    Gilgit-Baltistan  Cannabis sativa          Thunchi
# 4      Pakistan    Gilgit-Baltistan  Cannabis sativa          Thunchi
# ...         ...                 ...              ...              ...
# 2326   Pakistan  Khyber Pakhtunkhwa  Cannabis sativa          Bhangay
# 2327   Pakistan  Khyber Pakhtunkhwa  Cannabis sativa          Bhangay
# 2328   Pakistan  Khyber Pakhtunkhwa  Cannabis sativa          Bhangay
# 2329   Pakistan  Khyber Pakhtunkhwa  Cannabis sativa          Bhangay
# 2330      India      Andhra Pradesh  Cannabis sativa       Ganjayiaku
#
#        Unnamed: 8 Plant parts used  ...  \
# 0     Destination               In  ...
# 1               H                0  ...
# 2               H                0  ...
# 3               H                0  ...
# 4               H                0  ...
# ...           ...              ...  ...
# 2326            H                1  ...
# 2327            H                1  ...
# 2328            H                1  ...
# 2329            H                1  ...
# 2330            H                0  ...
#
#                                             Unnamed: 28 Unnamed: 29  \
# 0     Alimentary use [vernacular names of foods and ...  Fibre use
# 1                                                   NaN         NaN
# 2                                                   NaN         NaN
# 3                                                   NaN         NaN
# 4                                                   NaN         NaN
# ...                                                 ...         ...
# 2326                                                NaN         NaN
# 2327                                                NaN         NaN
# 2328                                                NaN         NaN
# 2329                                                NaN         NaN
# 2330                                                NaN         NaN
#
#                               Unnamed: 30 Unnamed: 31            Unnamed: 32  \
# 0     Psychoactive use [vernacular names]    Toxicity  Other uses categories
# 1                                     NaN         NaN                    NaN
# 2                                     NaN         NaN                    NaN
# 3                                     NaN         NaN                    NaN
# 4                                     NaN         NaN                    NaN
# ...                                   ...         ...                    ...
# 2326                                  NaN         NaN                    NaN
# 2327                                  NaN         NaN                    NaN
# 2328                                  NaN         NaN                    NaN
# 2329                                  NaN         NaN                    NaN
# 2330                                  NaN         NaN                    NaN
#
#      Unnamed: 33 Unnamed: 34              Unnamed: 35  \
# 0     Other uses     Mixture  Internal / External use
# 1            NaN           0                      NaN
# 2            NaN           0                      NaN
# 3            NaN           0                      NaN
# 4            NaN           0                      NaN
# ...          ...         ...                      ...
# 2326         NaN           0                      NaN
# 2327         NaN           0                      NaN
# 2328         NaN           0                      NaN
# 2329         NaN           0                      NaN
# 2330         NaN           1                      Int
#
#                                             Unnamed: 36  \
# 0     Preparation and administration [vernacular names]
# 1                                                   NaN
# 2                                           Direct use.
# 3                                           Direct use.
# 4                                           Direct use.
# ...                                                 ...
# 2326  The plant is also used in various medications ...
# 2327  The plant is also used in various medications ...
# 2328  The plant is also used in various medications ...
# 2329  The plant is also used in various medications ...
# 2330  1 g of Cannabis sativa leaves and 3 nos of fre...
#
#                  Unnamed: 37
# 0     Additional information
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 2326                     NaN
# 2327                     NaN
# 2328                     NaN
# 2329                     NaN
# 2330                     NaN
#
# [2331 rows x 38 columns]
